# %% [markdown]
# <a href="https://colab.research.google.com/github/kishore2963/Blank/blob/main/Copy_of_Data_Structures_Hands_On_PI_Session_G01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Strutures
# # Debugging using various sources

# %% [markdown]
# Linked List
# Graphs Network Graphs
#
#
# ![image.png](data:image/png;base64,...)

# %%
"quick", "brown","fox"

# %%
class Node:
    """ A singly-linked node. """
    def __init__(self, data=None):
        self.data = data
        self.next = None

class SinglyLinkedList:
    """ A singly-linked list. """
    def __init__(self):
        """ Create an empty list. """
        self.tail = None
        self.head = None
        self.count = 0

    def iter(self):
        """ Iterate through the list. """
        current = self.tail
        while current:
            val = current.data
            current = current.next
            yield val

    def append(self, data):
        """ Append an item to the list """
        node = Node(data)
        if self.head:
            self.head.next = node
            self.head = node
        else:
            self.tail = node
            self.head = node
        self.count += 1

    def delete(self, data):
        """ Delete a node from the list """
        current = self.tail
        prev = self.tail
        while current:
            if current.data == data:
                if current == self.tail:
                    self.tail = current.next
                else:
                    prev.next = current.next
                self.count -= 1
                return
            prev = current
            current = current.next

    def search(self, data):
        """ Search through the list. Return True if data is found, otherwise
        False. """
        for node in self.iter():
            if data == node:
                return True
        return False

    def __getitem__(self, index):
        if index > self.count - 1:
            raise Exception("Index out of range.")
        current = self.tail
        for n in range(index):
            current = current.next
        return current.data

    def __setitem__(self, index, value):
        if index > self.count - 1:
            raise Exception("Index out of range.")
        current = self.tail
        for n in range(index):
            current = current.next
        current.data = value

# %%
words= SinglyLinkedList()

# %%
words.append('quick')
words.append('brown')
words.append('fox')
words.append('jumps')
words.append('over')
words.append('lazy')
words.append('dog')

# %%
print("access by index")
print("here is a node: {}".format(words[4]))
# Out:
# access by index
# here is a node: OVER

# %%
words[4]='OVER'

# %%
print("This list has {} elements.".format(words.count))
# Out:
# This list has 7 elements.

# %%
for word in words.iter():
    print("Got this data: {}".format(word))
# Out:
# Got this data: quick
# Got this data: brown
# Got this data: fox
# Got this data: jumps
# Got this data: OVER
# Got this data: lazy
# Got this data: dog

# %%
if words.search('dog'):
  print(True)
else:
  print(False)
# Out:
# True

# %% [markdown]
# Stack & queue
#
# # stack
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Undo
# backtrack
# reverse string
# compilers -> stack

# %% [markdown]
# # queue
# ![image.png](data:image/png;base64,...)

# %%
# FIFO
# printer

# %% [markdown]
# Implementation of Stack
# Stack Attributes and Methods
# Stack() creates a new stack that is empty. It needs no parameters and returns an empty stack.
# push(item) adds a new item to the top of the stack. It needs the item and returns nothing.
# pop() removes the top item from the stack. It needs no parameters and returns the item. The stack is modified.
# peek() returns the top item from the stack but does not remove it. It needs no parameters. The stack is not modified.
# isEmpty() tests to see whether the stack is empty. It needs no parameters and returns a boolean value.
# size() returns the number of items on the stack. It needs no parameters and returns an integer.

# %%
class Stack():
    '''implementing3 stack using list'''
    
    def __init__(self):
        self.items=[]
    
    def isEmpty(self):
        '''check for emplty stack'''
        #self.items == []            --> emplty stack
        return len(self.items)==0  # --> len(stack)-zero
    
    def push(self,item):
        '''push value in stack'''
        self.items.append(item)
        
    def pop(self):
        '''pops value from stack and returns it'''
        #check length before popping
        if len(self.items) == 0:
            return None
        return self.items.pop()
    
    def peek(self):
        '''return top most value of stack'''
        #check length before peeking
        if len(self.items) == 0:
            return None
        
        return self.items[len(self.items)-1]
    
    def size(self):
        '''return size of stack'''
        return len(self.items)

# %%
s=Stack()

# %%
s.isEmpty()
# Out:
# True

# %%
s.push(1)

s.push("two")

s.push(True)

s.push("three")

# %%
s.peek()
# Out:
# 'three'

# %%
s.size()
# Out:
# 4

# %%
s.pop()
# Out:
# 'three'

# %%
s.size()
# Out:
# 3

# %%
s.pop()
# Out:
# True

# %%
s.pop()
# Out:
# 'two'

# %%
s.pop()
# Out:
# 1

# %%
s.size()
# Out:
# 0

# %%
s.isEmpty()
# Out:
# True

# %%
class Queue:
    '''implementing Queue using list'''
    
    def __init__(self):
        self.items = []

    def isEmpty(self):
        '''check for emplty Queue'''
        #self.items == []            --> emplty stack
        return len(self.items)==0  # --> len(stack)-zero

    def enqueue(self, item):
        '''push value in Queue'''
        self.items.insert(0,item)

    def dequeue(self):
        '''pops value from Queue and returns it'''
        #check length before popping
        if len(self.items) == 0:
            return None
        return self.items.pop()
    
    def peek(self):
        '''return top most value of Queue'''
        #check length before peeking
        if len(self.items) == 0:
            return None
        
        return self.items[len(self.items)-1]

    def size(self):
        '''return size of Queue'''
        return len(self.items)

# %% [markdown]
# # Graphs
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph():
    '''
    Graph implementation using adjacency list,undirected and non weighted grpah
    '''
    
    def __init__(self,nodes):
        self.nodes=nodes
        self.adj_list={}
        
        for i in self.nodes:
            self.adj_list[i]=[]
        
    def add_node(self,u):
        self.adj_list[u]=[]
        self.nodes.append(u)
        
    def add_edge(self,u,v):
        self.adj_list[u].append(v)
        self.adj_list[v].append(u)
                    
    def display(self):
        for i in self.nodes:
            print(i, '-->' , self.adj_list[i])
    
    def is_connected(self,u,v):
        return self.adj_list[u].count(v)==1
    
    def degree(self,node):
        #no of connecting edges 
        return len(self.adj_list[node])
    
    def no_of_nodes(self):
        return len(self.adj_list)

# %%
#vertices:
nodes=['A','B','C','D','E']
#edges:
all_edges=[('A','B'),('A','C'),('B','D'),('C','D'),('C','E'),('D','E')]

# %%
mygrpah=Graph(nodes)

# %%
mygrpah.display()
# Out:
# A --> []
# B --> []
# C --> []
# D --> []
# E --> []

# %%
for u,v in all_edges:
    mygrpah.add_edge(u,v)

mygrpah.display()
# Out:
# A --> ['B', 'C']
# B --> ['A', 'D']
# C --> ['A', 'D', 'E']
# D --> ['B', 'C', 'E']
# E --> ['C', 'D']

# %%
mygrpah.degree('D')
# Out:
# 3

# %%
mygrpah.degree('A')
# Out:
# 2

# %%
# "string".split("r")

# pandas

# df.shape  static method
# df.apply(converttostring) instance method


# df.drop('salary', axis=1)
#class method
#abstract

# value 
df['column'].values
date.today()

today().get_value()     

# mygrpah.is_connected('A','C')
# Out:
# ['st', 'ing']

# %%
class Graph():
    '''
    Graph implementation using adjacency list,directed and non weighted grpah
    '''
    
    def __init__(self,nodes,is_directed):
        self.nodes=nodes
        self.is_directed=is_directed
        self.adj_list={}
        
        for i in self.nodes:
            self.adj_list[i]=[]
        
    def add_node(self,u):
        # local varible weight or the global 
        # self.adj_list[u]=[]
        # self.nodes.append(u)
        self.weight.append(u)
        
    def add_edge(self,u,v):
        self.adj_list[u].append(v)
        if not self.is_directed:
            self.adj_list[v].append(u)

                    
    def display(self):
        for i in self.nodes:
            print(i, '-->' , self.adj_list[i])
    
    def is_connected(self,u,v):
        return self.adj_list[u].count(v)==1
    
    def degree(self,node):
        #no of connecting edges 
        return len(self.adj_list[node])
    
    def no_of_nodes(self):  ## static 
        return len(self.adj_list)

# %%
class bankaccount()

balance check

Instance
Static

# %%
# shortestpath.py
import osmnx as ox
import networkx as nx
ox.settings.log_console=True
ox.settings.use_cache=True# define the start and end locations in latlng
start_latlng = (37.78497,-122.43327)
end_latlng = (37.78071,-122.41445)# location where you want to find your route
place     = 'San Francisco, California, United States'# find shortest route based on the mode of travel
mode      = 'walk'        # 'drive', 'bike', 'walk'# find shortest path based on distance or time
optimizer = 'time'        # 'length','time'# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)# find the nearest node to the start location
orig_node = ox.distance.nearest_nodes(graph, start_latlng[1],
                                      start_latlng[0])# find the nearest node to the end location
dest_node = ox.distance.nearest_nodes(graph, end_latlng[1],
                                      end_latlng[0])#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
shortest_route_map = ox.plot_route_folium(graph, shortest_route)
shortest_route_map
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf . Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-158f8b9cec5c> in <cell line: 12>()
#      10 optimizer = 'time'        # 'length','time'# create graph from OSM within the boundaries of some
#      11 # geocodable place(s)
# ---> 12 graph = ox.graph_from_place(place, network_type = mode)# find the nearest node to the start location
#      13 orig_node = ox.distance.nearest_nodes(graph, start_latlng[1],
#      14                                       start_latlng[0])# find the nearest node to the end location
#
# /usr/local/lib/python3.9/dist-packages/osmnx/graph.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, buffer_dist, clean_periphery, custom_filter)
#     349
#     350     # create graph using this polygon(s) geometry
# --> 351     G = graph_from_polygon(
#     352         polygon,
#     353         network_type=network_type,
#
# /usr/local/lib/python3.9/dist-packages/osmnx/graph.py in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     444         # simplify the graph topology
#     445         if simplify:
# --> 446             G_buff = simplification.simplify_graph(G_buff)
#     447
#     448         # truncate graph by original polygon to return graph within polygon
#
# /usr/local/lib/python3.9/dist-packages/osmnx/simplification.py in simplify_graph(G, strict, remove_rings, track_merged)
#     299                     # if this key doesn't already exist, set the value to a list
#     300                     # containing the one value
# --> 301                     path_attributes[attr] = [edge_data[attr]]
#     302
#     303         # consolidate the path's edge segments' attribute values
#
# KeyboardInterrupt:

# %%
# !pip install osmnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting osmnx
#   Downloading osmnx-1.3.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.9/dist-packages (from osmnx) (3.1)
# Collecting pyproj>=3.4
#   Downloading pyproj-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.9/dist-packages (from osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8 in /usr/local/lib/python3.9/dist-packages (from osmnx) (2.8.2)
# Requirement already satisfied: Shapely>=2.0 in /usr/local/lib/python3.9/dist-packages (from osmnx) (2.0.1)
# Collecting requests>=2.28
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.9/dist-packages (from osmnx) (1.5.3)
# Collecting numpy>=1.23
#   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 33.3 MB/s eta 0:00:00
# Collecting geopandas>=0.12
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.7 MB/s eta 0:00:00
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 43.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas>=0.12->osmnx) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.5->osmnx) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.5->osmnx) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from pyproj>=3.4->osmnx) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8->osmnx) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28->osmnx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28->osmnx) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.28->osmnx) (1.26.15)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (8.1.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (6.4.1)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->osmnx) (3.15.0)
# Installing collected packages: requests, pyproj, numpy, munch, cligj, click-plugins, fiona, geopandas, osmnx
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.3 geopandas-0.12.2 munch-2.5.0 numpy-1.24.2 osmnx-1.3.0 pyproj-3.5.0 requests-2.28.2
